# %%
import pandas as pd

scores = [
    {'chinese':78,'english':80,'math':92,'history':75,'discover':85},
    {'chinese':92,'english':60,'math':85,'history':62,'discover':73}
]
dataFrame = pd.DataFrame(index=["不是乾男",'也不是乾男'],data = scores)
display(dataFrame.T)
# Out:
#           不是乾男  也不是乾男
# chinese     78     92
# english     80     60
# math        92     85
# history     75     62
# discover    85     73

# %%
display(dataFrame.T.plot())
display(dataFrame.plot())
# Out:
# <Axes: >
# <Axes: >

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r'c:\WINDOWS\Fonts\GENSENROUNDED-R.TTC',size=24)
figure = plt.figure()  #畫布
axes = figure.add_subplot(1,1,1) #傳出圖表
dataFrame.T.plot(ax=axes,style=['-','--'],marker = 'o')  #畫在這個畫布上
axes.set_title("分數比較表",fontproperties=font)
axes.grid(visible=True,axis='y') #grid  #axie可以自己來管，用dataFrame.plot來畫
plt.show()

#自動加入axes.legend
# Out:
# C:\Users\tm912\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\tm912\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\tm912\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20094 (\N{CJK UNIFIED IDEOGRAPH-4E7E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\tm912\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30007 (\N{CJK UNIFIED IDEOGRAPH-7537}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\tm912\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20063 (\N{CJK UNIFIED IDEOGRAPH-4E5F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
